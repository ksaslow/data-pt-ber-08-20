# %%
import json
import requests
import pandas as pd
import re

# %%
# import json

# cred = {} 
# cred['user_name'] = user_name
# cred['token'] = token

# with open('github_cred.json', 'w') as outfile:
#     json.dump(cred, outfile)

# %% [markdown]
# ### Challenge 1: Forks

# %% [markdown]
# #### Obtain the full list of forks created from the main lab repo via the Github API.

# %%
# Create variables which contain your user name and your token
# user_name =
# token =

# %%
# Retrieve a json file with information on all of the forks. You will need an "auth" argument here for authentication!

requests.get('https://api.github.com/user', auth=(user_name, token))
# found online, the help function didnt give arguments for auth method!

response = requests.get('https://api.github.com/repos/ironhack-datalabs/data-pt-ber-08-20/forks', auth=(user_name, token))

# %%
response
# Out:
# <Response [200]>

# %%
# pd.read_json?

# %%
# requests.get?

# %%
# Normalize semi-structured JSON data into a dataframe. 
data = response.json()
data
forks = pd.json_normalize(data)
forks
set(forks)
# Out:
# {'archive_url',
#  'archived',
#  'assignees_url',
#  'blobs_url',
#  'branches_url',
#  'clone_url',
#  'collaborators_url',
#  'comments_url',
#  'commits_url',
#  'compare_url',
#  'contents_url',
#  'contributors_url',
#  'created_at',
#  'default_branch',
#  'deployments_url',
#  'description',
#  'disabled',
#  'downloads_url',
#  'events_url',
#  'fork',
#  'forks',
#  'forks_count',
#  'forks_url',
#  'full_name',
#  'git_commits_url',
#  'git_refs_url',
#  'git_tags_url',
#  'git_url',
#  'has_downloads',
#  'has_issues',
#  'has_pages',
#  'has_projects',
#  'has_wiki',
#  'homepage',
#  'hooks_url',
#  'html_url',
#  'id',
#  'issue_comment_url',
#  'issue_events_url',
#  'issues_url',
#  'keys_url',
#  'labels_url',
#  'language',
#  'languages_url',
#  'license',
#  'license.key',
#  'license.name',
#  'license.node_id',
#  'license.spdx_id',
#  'license.url',
#  'merges_url',
#  'milestones_url',
#  'mirror_url',
#  'name',
#  'node_id',
#  'notifications_url',
#  'open_issues',
#  'open_issues_count',
#  'owner.avatar_url',
#  'owner.events_url',
#  'owner.followers_url',
#  'owner.following_url',
#  'owner.gists_url',
#  'owner.gravatar_id',
#  'owner.html_url',
#  'owner.id',
#  'owner.login',
#  'owner.node_id',
#  'owner.organizations_url',
#  'owner.received_events_url',
#  'owner.repos_url',
#  'owner.site_admin',
#  'owner.starred_url',
#  'owner.subscriptions_url',
#  'owner.type',
#  'owner.url',
#  'permissions.admin',
#  'permissions.pull',
#  'permissions.push',
#  'private',
#  'pulls_url',
#  'pushed_at',
#  'releases_url',
#  'size',
#  'ssh_url',
#  'stargazers_count',
#  'stargazers_url',
#  'statuses_url',
#  'subscribers_url',
#  'subscription_url',
#  'svn_url',
#  'tags_url',
#  'teams_url',
#  'trees_url',
#  'updated_at',
#  'url',
#  'watchers',
#  'watchers_count'}

# %%
forks['owner.login']
# Out:
# 0         Abdou-Man-24
# 1              Seetank
# 2         joao-dias-25
# 3      filipamiralopes
# 4         sholaayodele
# 5           danielquer
# 6     BehroozGharleghi
# 7           Ayomi-tech
# 8             Najla-Sh
# 9          Shinan-tech
# 10             ksaslow
# 11             cabulut
# 12       davidegonzale
# 13        vikkieessien
# 14           Benedkt93
# 15        thomas-cares
# 16       christinahans
# 17           pepenunez
# Name: owner.login, dtype: object

# %% [markdown]
# #### Extract a list of all the usernames of people who have forked this repo.

# %%
# Your code:
full_names = forks['full_name']
usernames = forks['owner.login']
usernames
# clean the data so you just have the usernames, not the repo too
# Out:
# 0         Abdou-Man-24
# 1              Seetank
# 2         joao-dias-25
# 3      filipamiralopes
# 4         sholaayodele
# 5           danielquer
# 6     BehroozGharleghi
# 7           Ayomi-tech
# 8             Najla-Sh
# 9          Shinan-tech
# 10             ksaslow
# 11             cabulut
# 12       davidegonzale
# 13        vikkieessien
# 14           Benedkt93
# 15        thomas-cares
# 16       christinahans
# 17           pepenunez
# Name: owner.login, dtype: object

# %% [markdown]
# ### Challenge 2: Count Commits

# %% [markdown]
# Obtain a dataframe which contains all of the commits made. From this dataframe, extract a list of all the commit messages. Also, count how many commits have been made.

# %%
# Your code:
response2 = requests.get('https://api.github.com/repos/ironhack-datalabs/data-pt-ber-08-20/commits', auth=(user_name, token))
response2
# Out:
# <Response [200]>

# %%
data2 = response2.json()
data2
commits = pd.json_normalize(data2)
commits
# Out:
#                                          sha  \
# 0   db4bdd83a9e0d2c7ca534819e02de836fe40af87
# 1   57c3ed5276961c7aff3b07ada7150d6a7039ec50
# 2   345719a6423495e5d21aeae9a9cea3da787729a6
# 3   4dbb1213b78e23b845251e12ae2389d2f6bd653d
# 4   212da9f2090430347f0614d9b094ddb3a4f98ff4
# 5   d79fe770a8da68b3bd579906a8b5a6cc38988fa3
# 6   31c5316c3e04e790fa3e393ebe9f67f55a343f04
# 7   dbda871347f31d996d382bf5e64606daae7b1168
# 8   7efdfc87a550d73bf4897d632a5a9f4e5feccc87
# 9   78ce571ff02ab2c384a521a5b095978ba12255bb
# 10  ebefe5930ec44dc6c85a7da6a70bfd157388f076
# 11  d492b5b0938fef50e4dbfc5599c2c44b79152d5f
# 12  8b693b361703ceb4cd48fcb5f27a5742579e0303
# 13  b90d3032ca387db8a089bec50f39a07c402716d7
# 14  1992694b107050728c9afc22c45208011856fa91
# 15  e842980cab6c7c2ea7ee5d2bda96fe2908b5e251
# 16  6d3ddcee6ad6cd347e2d624fce28e1f464a41603
# 17  7fe797f3eb833e54b6eadd678afb780af297a2a8
# 18  d6b0c94505267a0d7240e562a9b347c60406db87
# 19  b312b6a56f2b55f06ec85836512fd10593ed6345
# 20  07d0a320c8785b7bdeb5c1a2fc41cdc2bfc780aa
# 21  2de08c3fd77acded7b365585faf5f2dab3283a93
# 22  9f698caecdf581eb165c790ee5912c909a6ee0f8
# 23  c26270ea1f3dcb74bada9a9159e13b4aabf2cb78
# 24  ced990b5949fd792fc03c0adc61ebc4aa0f30e1e
# 25  c4644ee464f3de53d857f187497a1fcc88935307
# 26  dc358f9c2b866ebcc3d479d7a5e608308e2641a7
# 27  3f3ab28f9af57d5c8615ca3064914edaa45bb783
# 28  5bfaba7353660f1e2613b9d9f90ce643847fa049
# 29  0f0e116de38d5c076411c97d9400dd003ac15a13
#
#                                               node_id  \
# 0   MDY6Q29tbWl0Mjg5ODkxODE1OmRiNGJkZDgzYTllMGQyYz...
# 27  https://github.com/ironhack-datalabs/data-pt-b...
# 28  https://github.com/ironhack-datalabs/data-pt-b...
# 29  https://github.com/ironhack-datalabs/data-pt-b...
#
#                                          comments_url author committer  \
# 0   https://api.github.com/repos/ironhack-datalabs...   None      None
# 1   https://api.github.com/repos/ironhack-datalabs...   None      None
# 2   https://api.github.com/repos/ironhack-datalabs...   None      None
# 3   https://api.github.com/repos/ironhack-datalabs...   None      None
# 4   https://api.github.com/repos/ironhack-datalabs...   None      None
# 5   https://api.github.com/repos/ironhack-datalabs...   None      None
# 6   https://api.github.com/repos/ironhack-datalabs...   None      None
# 7   https://api.github.com/repos/ironhack-datalabs...   None      None
# 8   https://api.github.com/repos/ironhack-datalabs...   None      None
# 9   https://api.github.com/repos/ironhack-datalabs...   None      None
# 10  https://api.github.com/repos/ironhack-datalabs...   None      None
# 11  https://api.github.com/repos/ironhack-datalabs...   None      None
# 12  https://api.github.com/repos/ironhack-datalabs...   None      None
# 13  https://api.github.com/repos/ironhack-datalabs...   None      None
# 14  https://api.github.com/repos/ironhack-datalabs...   None      None
# 15  https://api.github.com/repos/ironhack-datalabs...   None      None
# 16  https://api.github.com/repos/ironhack-datalabs...   None      None
# 17  https://api.github.com/repos/ironhack-datalabs...   None      None
# 18  https://api.github.com/repos/ironhack-datalabs...   None      None
# 19  https://api.github.com/repos/ironhack-datalabs...   None      None
# 20  https://api.github.com/repos/ironhack-datalabs...   None      None
# 21  https://api.github.com/repos/ironhack-datalabs...   None      None
# 22  https://api.github.com/repos/ironhack-datalabs...   None      None
# 23  https://api.github.com/repos/ironhack-datalabs...   None      None
# 24  https://api.github.com/repos/ironhack-datalabs...   None      None
# 25  https://api.github.com/repos/ironhack-datalabs...   None      None
# 26  https://api.github.com/repos/ironhack-datalabs...   None      None
# 27  https://api.github.com/repos/ironhack-datalabs...   None      None
# 28  https://api.github.com/repos/ironhack-datalabs...   None      None
# 29  https://api.github.com/repos/ironhack-datalabs...   None      None
#
#                                               parents commit.author.name  \
# 0   [{'sha': '57c3ed5276961c7aff3b07ada7150d6a7039...             Filipa
# 1   [{'sha': '345719a6423495e5d21aeae9a9cea3da7877...             Filipa
# 2   [{'sha': '4dbb1213b78e23b845251e12ae2389d2f6bd...             Filipa
# 3   [{'sha': '212da9f2090430347f0614d9b094ddb3a4f9...             Filipa
# 4   [{'sha': 'd79fe770a8da68b3bd579906a8b5a6cc3898...             Filipa
# 5   [{'sha': '31c5316c3e04e790fa3e393ebe9f67f55a34...             Filipa
# 6   [{'sha': 'dbda871347f31d996d382bf5e64606daae7b...     Christina Hans
# 7   [{'sha': 'ebefe5930ec44dc6c85a7da6a70bfd157388...     Christina Hans
# 8   [{'sha': '78ce571ff02ab2c384a521a5b095978ba122...             Filipa
# 9   [{'sha': 'd492b5b0938fef50e4dbfc5599c2c44b7915...             Filipa
# 10  [{'sha': 'd492b5b0938fef50e4dbfc5599c2c44b7915...     Christina Hans
# 11  [{'sha': '8b693b361703ceb4cd48fcb5f27a5742579e...     Christina Hans
# 12  [{'sha': 'b90d3032ca387db8a089bec50f39a07c4027...             Filipa
# 25  christina@koekoetech.com  ...  2020-09-24T14:32:24Z
# 26  christina@koekoetech.com  ...  2020-09-24T13:33:18Z
# 27  christina@koekoetech.com  ...  2020-09-24T13:04:55Z
# 28  christina@koekoetech.com  ...  2020-09-24T13:04:51Z
# 29         filipa@lateral.io  ...  2020-09-23T12:04:05Z
#
#                                        commit.message  \
# 0                      api-scavenger-game - solutions
# 1                            adding twitter-api class
# 2                         adding error_messages class
# 3                         solutions lab-coingecko-api
# 4                                    adding api-class
# 5                        solutions lab-advanced-regex
# 6   Merge branch 'master' of https://github.com/ir...
# 7                                           scavenger
# 8   Merge branch 'master' of https://github.com/ir...
# 9                                class advanced regex
# 10                                            project
# 11                                      coingecko api
# 12                         solutions lab-web-scraping
# 13                          adding web-scraping-class
# 14  Merge branch 'master' of https://github.com/ir...
# 15                                   web scraping lab
# 16                      solutions basics_plotting lab
# 17                       adding plotting-basics-class
# 18                                 basic plotting lab
# 19                                      rem solutions
# 20                        solutions lab-data_cleaning
# 21     solutions ab-df-calculation-and-transformation
# 22                 last exercise challenge 1 adjusted
# 23  solutions lab data calculation-and-transformat...
# 24                      data manipulation class added
# 25                                  data cleaning lab
# 26                             df transformations lab
# 27  Merge branch 'master' of https://github.com/ir...
# 28                             df transformations lab
# 29                       solutions lab action queries
#
#                              commit.tree.sha  \
# 0   25be7c05bf3d0777f63ed6b0be81836cdd938865
# 1   224035b16bbda82ae2a2373467ef38d61c2baec0
# 2   bf4bc17b7d80f623144b321e12d845d1587c32e0
# 3   c6a75c85f68ccb6c810057f9194cf560afbdcd0b
# 4   5327d49b3cdd512264fe9a8d125818ee5364b725
# 5   a6b757583864ed1971977466cc0c5a34c82aeeaf
# 6   1ebae9af890f600268efe31e974500a09aea8925
# 7   246019e7aaa3551e2726c7edd6baef9052556529
# 8   8b963256d1cf60b8eead13cf3b0b46b4cdb4a6f7
# 9   60a539f821d3677470f337f2c1623fd042a052e8
# 10  c68f61744b2de270738ed1d905e1226b40e9affd
# 11  516e00e85695418141b337f3307e10ca46a8abbf
# 12  ef5dd7c8dfa228914a4c7802753f6f64d567faa5
# 13  ae307d6c7094ef824f327293648ed23cbedb872c
# 14  4f2f3fb6dfd2a636f7f7c270e8a39955edb3b9bb
# 15  10ca2c5fe398a185896748ebf068d6f25a523d1b
# 16  80043e89f9abf68c62c0a9c10046c1e9c9e735f4
# 17  05c0abf27c46d06a765f3ec6f813838572863c72
# 18  58d427c55f2d4c94aa03765be42448b0a212f13c
# 19  c9c5d7d64af85386050cd4baf208d5b88061b731
# 20  562bc84c8c42d8500182215112b42a5e5d9aaaa2
# 21  6daaabe9b19dfe259920ad857bec0024e57e3892
# 22  03cea95100ccb8ff55bc3d49573b462a220562c9
# 23  04928e92bb756ad7dc09ec58bbbbed9358028cb4
# 24  6850f889a1745bb90c78155e9c015afb63fd55bb
# 25  e9b8383602dbd90e27df8a78746e18fc0b7aefd7
# 26  e635adb3dfb4666c1fb08682e0650a5b285f2052
# 27  753d1ec0888867aadcd63fccd8904217bfd9291c
# 28  1127896a8361ada6a82db9cbcf1ebeda9147ee52
# 29  ea8b2951ccfad21b60bf9eabc20e331895b6bbe0
#
#                                       commit.tree.url  \
# 0   https://api.github.com/repos/ironhack-datalabs...
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 3   https://api.github.com/repos/ironhack-datalabs...
# 4   https://api.github.com/repos/ironhack-datalabs...
# 5   https://api.github.com/repos/ironhack-datalabs...
# 6   https://api.github.com/repos/ironhack-datalabs...
# 7   https://api.github.com/repos/ironhack-datalabs...
# 8   https://api.github.com/repos/ironhack-datalabs...
# 9   https://api.github.com/repos/ironhack-datalabs...
# 10  https://api.github.com/repos/ironhack-datalabs...
# 11  https://api.github.com/repos/ironhack-datalabs...
# 12  https://api.github.com/repos/ironhack-datalabs...
# 13  https://api.github.com/repos/ironhack-datalabs...
# 14  https://api.github.com/repos/ironhack-datalabs...
# 15  https://api.github.com/repos/ironhack-datalabs...
# 16  https://api.github.com/repos/ironhack-datalabs...
# 17  https://api.github.com/repos/ironhack-datalabs...
# 18  https://api.github.com/repos/ironhack-datalabs...
# 19  https://api.github.com/repos/ironhack-datalabs...
# 20  https://api.github.com/repos/ironhack-datalabs...
# 21  https://api.github.com/repos/ironhack-datalabs...
# 22  https://api.github.com/repos/ironhack-datalabs...
# 23  https://api.github.com/repos/ironhack-datalabs...
# 24  https://api.github.com/repos/ironhack-datalabs...
# 25  https://api.github.com/repos/ironhack-datalabs...
# 26  https://api.github.com/repos/ironhack-datalabs...
# 27  https://api.github.com/repos/ironhack-datalabs...
# 28  https://api.github.com/repos/ironhack-datalabs...
# 29  https://api.github.com/repos/ironhack-datalabs...
#
#                                            commit.url commit.comment_count  \
# 0   https://api.github.com/repos/ironhack-datalabs...                    0
# 1   https://api.github.com/repos/ironhack-datalabs...                    0
# 2   https://api.github.com/repos/ironhack-datalabs...                    0
# 3   https://api.github.com/repos/ironhack-datalabs...                    0
# 4   https://api.github.com/repos/ironhack-datalabs...                    0
# 5   https://api.github.com/repos/ironhack-datalabs...                    0
# 6   https://api.github.com/repos/ironhack-datalabs...                    0
# 7   https://api.github.com/repos/ironhack-datalabs...                    0
# 8   https://api.github.com/repos/ironhack-datalabs...                    0
# 9   https://api.github.com/repos/ironhack-datalabs...                    0
# 10  https://api.github.com/repos/ironhack-datalabs...                    0
# 11  https://api.github.com/repos/ironhack-datalabs...                    0
# 12  https://api.github.com/repos/ironhack-datalabs...                    0
# 13  https://api.github.com/repos/ironhack-datalabs...                    0
# 14  https://api.github.com/repos/ironhack-datalabs...                    0
# 15  https://api.github.com/repos/ironhack-datalabs...                    0
# 16  https://api.github.com/repos/ironhack-datalabs...                    0
# 17  https://api.github.com/repos/ironhack-datalabs...                    0
# 18  https://api.github.com/repos/ironhack-datalabs...                    0
# 19  https://api.github.com/repos/ironhack-datalabs...                    0
# 20  https://api.github.com/repos/ironhack-datalabs...                    0
# 21  https://api.github.com/repos/ironhack-datalabs...                    0
# 22  https://api.github.com/repos/ironhack-datalabs...                    0
# 23  https://api.github.com/repos/ironhack-datalabs...                    0
# 24  https://api.github.com/repos/ironhack-datalabs...                    0
# 25  https://api.github.com/repos/ironhack-datalabs...                    0
# 26  https://api.github.com/repos/ironhack-datalabs...                    0
# 27  https://api.github.com/repos/ironhack-datalabs...                    0
# 28  https://api.github.com/repos/ironhack-datalabs...                    0
# 29  https://api.github.com/repos/ironhack-datalabs...                    0
#
#    commit.verification.verified commit.verification.reason  \
# 0                         False                   unsigned
# 1                         False                   unsigned
# 2                         False                   unsigned
# 3                         False                   unsigned
# 4                         False                   unsigned
# 5                         False                   unsigned
# 6                         False                   unsigned
# 7                         False                   unsigned
# 8                         False                   unsigned
# 9                         False                   unsigned
# 10                        False                   unsigned
# 11                        False                   unsigned
# 12                        False                   unsigned
# 13                        False                   unsigned
# 14                        False                   unsigned
# 15                        False                   unsigned
# 16                        False                   unsigned
# 17                        False                   unsigned
# 18                        False                   unsigned
# 19                        False                   unsigned
# 20                        False                   unsigned
# 21                        False                   unsigned
# 22                        False                   unsigned
# 23                        False                   unsigned
# 24                        False                   unsigned
# 25                        False                   unsigned
# 26                        False                   unsigned
# 27                        False                   unsigned
# 28                        False                   unsigned
# 29                        False                   unsigned
#
#     commit.verification.signature  commit.verification.payload
# 0                            None                         None
# 1                            None                         None
# 2                            None                         None
# 3                            None                         None
# 4                            None                         None
# 5                            None                         None
# 6                            None                         None
# 7                            None                         None
# 8                            None                         None
# 9                            None                         None
# 10                           None                         None
# 11                           None                         None
# 12                           None                         None
# 13                           None                         None
# 14                           None                         None
# 15                           None                         None
# 16                           None                         None
# 17                           None                         None
# 18                           None                         None
# 19                           None                         None
# 20                           None                         None
# 21                           None                         None
# 22                           None                         None
# 23                           None                         None
# 24                           None                         None
# 25                           None                         None
# 26                           None                         None
# 27                           None                         None
# 28                           None                         None
# 29                           None                         None
#
# [30 rows x 23 columns]

# %%
commit_messages = commits['commit.message']
print(commit_messages)

print("There were :" ,commit_messages.count(), "commits made")
# Out:
# 0                        api-scavenger-game - solutions
# 1                              adding twitter-api class
# 2                           adding error_messages class
# 3                           solutions lab-coingecko-api
# 4                                      adding api-class
# 5                          solutions lab-advanced-regex
# 6     Merge branch 'master' of https://github.com/ir...
# 7                                             scavenger
# 8     Merge branch 'master' of https://github.com/ir...
# 9                                  class advanced regex
# 10                                              project
# 11                                        coingecko api
# 12                           solutions lab-web-scraping
# 13                            adding web-scraping-class
# 14    Merge branch 'master' of https://github.com/ir...
# 15                                     web scraping lab
# 16                        solutions basics_plotting lab
# 17                         adding plotting-basics-class
# 18                                   basic plotting lab
# 19                                        rem solutions
# 20                          solutions lab-data_cleaning
# 21       solutions ab-df-calculation-and-transformation
# 22                   last exercise challenge 1 adjusted
# 23    solutions lab data calculation-and-transformat...
# 24                        data manipulation class added
# 25                                    data cleaning lab
# 26                               df transformations lab
# 27    Merge branch 'master' of https://github.com/ir...
# 28                               df transformations lab
# 29                         solutions lab action queries
# Name: commit.message, dtype: object
# There were : 30 commits made

# %% [markdown]
# #### Bonus Challenge: Obtain all of the commits that have been made in the past week (specify the date using a 'since' argument).

# %%
# Your code:
