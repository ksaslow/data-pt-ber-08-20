# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request

# from urllib.request import urlopen
# import random
import re
# # import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code

def make_soup(url):
    html = requests.get(url).content
    return BeautifulSoup(html, 'html.parser')
    

soup = make_soup('https://github.com/trending/developers')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-415d593418d9cfcb2d3f1fae87864029.css" integrity="sha512-QV1ZNBjZz8stPx+uh4ZAKc6AJ1z8A9VHut/SGtgbc+iYLfhrh68QmDH3rZgkXJ0BWIOcDw+ILnWcctH0ljcHPg==" media="all" rel="stylesheet">
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['JaredPalmer',
#  'MaëlNison',
#  'JacobHoffman-Andrews',
#  'PySimpleGUI',
#  'ChristianMuehlhaeuser',
#  'FranckNijhof',
#  'hackerman',
#  'DotanSimha',
#  'damienbod',
#  'MatthiasUrhahn',
#  'JasonMiller',
#  'ConnorClark',
#  'TaylorOtwell',
#  'SindreSorhus',
#  'VítorGalvão',
#  'jcesarmobile',
#  'EvgeniGolov',
#  'AnuragHazra',
#  'JamesNewton-King',
#  'MiekGieben',
#  'MeganMarsh',
#  'DomenicDenicola',
#  'WilliamCandillon',
#  'NormanMaurer',
#  'TimGroßmann']
#  ```

# %%
#your code

names = soup.find_all('h1', {'class': 'h3 lh-condensed'}) # you have to inspect the individual element with DevTools to see what youre actually searching for/specifying!

trending_developers = [i.text.strip() for i in names] # strip away the empty white space before/after
trending_developers
# Out:
# ['Sebastián Ramírez',
#  'Remi Rousselet',
#  'Stephan Dilly',
#  'Jesse Duffield',
#  'Peter Thaleikis',
#  'Henrik Rydgård',
#  'Thomas Lovén',
#  'Sridhar Ratnakumar',
#  'Alex Gaynor',
#  'Vladimir Mihailenco',
#  'Francois Zaninotto',
#  'Arvid Norberg',
#  'Joe Block',
#  'Avelino',
#  'An Tao',
#  'Christian Muehlhaeuser',
#  'Ned Batchelder',
#  'Tobias Koppers',
#  '偏右',
#  'Mike Penz',
#  'Steve Smith',
#  'Vadim Dalecky',
#  'Saket Narayan',
#  'Jaana Dogan',
#  'David Tolnay']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.
#
# Your output should look like below:
#
# ```
# ['anandpawara/Real_Time_Image_Animation',
#  'apprenticeharper/DeDRM_tools',
#  'donnemartin/system-design-primer',
#  'mingrammer/diagrams',
#  'facebookresearch/detr',
#  'google-research/football',
#  'domokane/FinancePy',
#  'qxresearch/qxresearch-event-1',
#  'remzi-arpacidusseau/ostep-homework',
#  'NVlabs/imaginaire',
#  'bridgecrewio/checkov',
#  'rvizzz/rotate',
#  'home-assistant/core',
#  'ytdl-org/youtube-dl',
#  'zdyshine/RTC2020_EfficientSR',
#  'vt-vl-lab/FGVC',
#  'microsoft/qlib',
#  'DataDog/integrations-core',
#  'Rudrabha/Wav2Lip',
#  'parzulpan/real-live',
#  'liangliangyy/DjangoBlog',
#  'boto/boto3',
#  'kov4l3nko/MEDUZA',
#  'Rapptz/discord.py',
#  'apache/airflow']
#  ```

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code

soup2 = make_soup('https://github.com/trending/python?since=daily')

repos = soup2.find_all('h1', {'class': 'h3 lh-condensed'})
trending_repos = [i.text.replace('/\n\n', '/').replace(' ', '').strip() for i in repos]
trending_repos
# Out:
# ['twintproject/twint',
#  'TurboWay/big_screen',
#  'The-Art-of-Hacking/h4cker',
#  'CorentinJ/Real-Time-Voice-Cloning',
#  'scikit-learn/scikit-learn',
#  'timgrossmann/InstaPy',
#  'home-assistant/core',
#  'ct-Open-Source/tuya-convert',
#  'ProgrammingHero1/audiobook',
#  'numpy/numpy',
#  'facebookresearch/TransCoder',
#  'python-geeks/Automation-scripts',
#  'Mebus/cupp',
#  'donnemartin/system-design-primer',
#  'pytorch/fairseq',
#  'jackfrued/Python-100-Days',
#  'thu-ml/tianshou',
#  'wagtail/wagtail',
#  'Ciphey/Ciphey',
#  'apprenticeharper/DeDRM_tools',
#  'bitcoin/bips',
#  'Pitt-CSC/Summer2021-Internships',
#  'Jrohy/multi-v2ray',
#  'tmrowco/electricitymap-contrib',
#  'megadose/holehe']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page
#
# Hint: once you have extracted the image links, you can find the link under link.attrs of each item, and you would like the attribute 'href' - print the link attrs to see what they look like. Careful! Not all of them might have the href attribute, so you need to generate your list using a for-loop with an if condition, that checks if this attribute is present.
#
#
# Your output should look like below:
#
# ```
# ['/wiki/File:Walt_Disney_1946.JPG',
#  '/wiki/File:Walt_Disney_1942_signature.svg',
#  '/wiki/File:Walt_Disney_envelope_ca._1921.jpg',
#  '/wiki/File:Trolley_Troubles_poster.jpg',
#  '/wiki/File:Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  '/wiki/File:Steamboat-willie.jpg',
#  '/wiki/File:Walt_Disney_1935.jpg',
#  '/wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg',
#  '/wiki/File:Disney_drawing_goofy.jpg',
#  '/wiki/File:DisneySchiphol1951.jpg',
#  '/wiki/File:WaltDisneyplansDisneylandDec1954.jpg',
#  '/wiki/File:Walt_disney_portrait_right.jpg',
#  '/wiki/File:Walt_Disney_Grave.JPG',
#  '/wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  '/wiki/File:Disney_Display_Case.JPG',
#  '/wiki/File:Disney1968.jpg',
#  '/wiki/File:The_Walt_Disney_Company_Logo.svg',
#  '/wiki/File:Animation_disc.svg',
#  '/wiki/File:P_vip.svg',
#  '/wiki/File:Magic_Kingdom_castle.jpg',
#  '/wiki/File:Video-x-generic.svg',
#  '/wiki/File:Flag_of_Los_Angeles_County,_California.svg',
#  '/wiki/File:Blank_television_set.svg',
#  '/wiki/File:Flag_of_the_United_States.svg']
#  ```

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
soup3.find_all?
# Out:
# Object `soup3.find_all` not found.

# %%
#your code

soup3 = make_soup('https://en.wikipedia.org/wiki/Walt_Disney')
images = soup3.find_all('a', {'class': 'image'})
images
# Out:
# [<a class="image" href="/wiki/File:Walt_Disney_1946.JPG"><img alt="Walt Disney 1946.JPG" data-file-height="675" data-file-width="450" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/330px-Walt_Disney_1946.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/440px-Walt_Disney_1946.JPG 2x" width="220"/></a>,
# ...

# %%
for i in images:
    print(i.get('href'))

# found this code online, dont fully understand how to add 'href' as an attribute to the find_all clause otherwise
# also my for loop doesn't use an if clause, it just uses the get method.
# Out:
# /wiki/File:Walt_Disney_1946.JPG
# /wiki/File:Walt_Disney_1942_signature.svg
# /wiki/File:Walt_Disney_envelope_ca._1921.jpg
# /wiki/File:Trolley_Troubles_poster.jpg
# /wiki/File:Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg
# /wiki/File:Steamboat-willie.jpg
# /wiki/File:Walt_Disney_1935.jpg
# /wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg
# /wiki/File:Disney_drawing_goofy.jpg
# /wiki/File:DisneySchiphol1951.jpg
# /wiki/File:WaltDisneyplansDisneylandDec1954.jpg
# /wiki/File:Walt_disney_portrait_right.jpg
# /wiki/File:Walt_Disney_Grave.JPG
# /wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg
# /wiki/File:Disney_Display_Case.JPG
# /wiki/File:Disney1968.jpg
# /wiki/File:The_Walt_Disney_Company_Logo.svg
# /wiki/File:Animation_disc.svg
# /wiki/File:P_vip.svg
# /wiki/File:Magic_Kingdom_castle.jpg
# /wiki/File:Video-x-generic.svg
# /wiki/File:Flag_of_Los_Angeles_County,_California.svg
# ...

# %% [markdown]
# #### Retrieve the Wikipedia page of "Python" and create a list of links on that page
#
# Your output should look like below:
#
# ```
# ['#mw-head',
#  '#searchInput',
#  'https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  '/wiki/Pythons',
#  '/wiki/Python_(genus)',
#  '#Computing',
#  '#People',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#Other_uses',
#  '#People_with_the_given_name',
#  '#See_also',
#  '/w/index.php?title=Python&action=edit&section=1',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
#  ...
#  ```

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code

soup4 = make_soup('https://en.wikipedia.org/wiki/Python')
soup4

pythons = soup4.find_all('a')
pythons

# pythons = soup4.find_all('a', attrs={'href'})
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#searchInput">Jump to search</a>,
#  <a class="extiw" href="https://en.wiktionary.org/wiki/Python" title="wiktionary:Python">Python</a>,
#  <a class="extiw" href="https://en.wiktionary.org/wiki/python" title="wiktionary:python">python</a>,
#  <a class="mw-redirect" href="/wiki/Pythons" title="Pythons">Pythons</a>,
#  <a href="/wiki/Python_(genus)" title="Python (genus)"><i>Python</i> (genus)</a>,
#  <a href="#Computing"><span class="tocnumber">1</span> <span class="toctext">Computing</span></a>,
#  <a href="#People"><span class="tocnumber">2</span> <span class="toctext">People</span></a>,
#  <a href="#Roller_coasters"><span class="tocnumber">3</span> <span class="toctext">Roller coasters</span></a>,
#  <a href="#Vehicles"><span class="tocnumber">4</span> <span class="toctext">Vehicles</span></a>,
# ...

# %%
for i in pythons:
    print(i.get('href'))
    
# same as images from wiki WaltDisney page. 
# still don't fully understand why
# Out:
# None
# #mw-head
# #searchInput
# https://en.wiktionary.org/wiki/Python
# https://en.wiktionary.org/wiki/python
# /wiki/Pythons
# /wiki/Python_(genus)
# #Computing
# #People
# #Roller_coasters
# #Vehicles
# #Weaponry
# #Other_uses
# #See_also
# /w/index.php?title=Python&action=edit&section=1
# /wiki/Python_(programming_language)
# /wiki/CMU_Common_Lisp
# /wiki/PERQ#PERQ_3
# /w/index.php?title=Python&action=edit&section=2
# /wiki/Python_of_Aenus
# /wiki/Python_(painter)
# /wiki/Python_of_Byzantium
# /wiki/Python_of_Catana
# /wiki/Python_Anghelo
# /w/index.php?title=Python&action=edit&section=3
# /wiki/Python_(Efteling)
# /wiki/Python_(Busch_Gardens_Tampa_Bay)
# /wiki/Python_(Coney_Island,_Cincinnati,_Ohio)
# /w/index.php?title=Python&action=edit&section=4
# /wiki/Python_(automobile_maker)
# /wiki/Python_(Ford_prototype)
# /w/index.php?title=Python&action=edit&section=5
# /wiki/Python_(missile)
# /wiki/Python_(nuclear_primary)
# /wiki/Colt_Python
# ...

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names
#
# Your output should look like below:
# ```
# ['ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'RAFAEL CARO-QUINTERO',
#  'YASER ABDEL SAID',
#  'SANTIAGO VILLALBA MEDEROS']
# ```

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 

soup5 = make_soup('https://www.fbi.gov/wanted/topten')
soup5

most_wanted = soup5.find_all('h3', {'class': 'title'})
most_wanted

[i.text.strip() for i in most_wanted]
# Out:
# ['EUGENE PALMER',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'YASER ABDEL SAID',
#  'SANTIAGO VILLALBA MEDEROS']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe
#
# Your output should look like below:
# ```
# 	0
# 0	PUERTO RICO REGION
# 1	ISLAND OF HAWAII, HAWAII
# 2	EASTERN TURKEY
# 3	MADEIRA ISLANDS, PORTUGAL REGION
# 4	NEAR EAST COAST OF HONSHU, JAPAN
# 5	OFFSHORE GUATEMALA
# 6	CENTRAL CALIFORNIA
# 7	TARAPACA, CHILE
# 8	OFF COAST OF COSTA RICA
# 9	SWITZERLAND
# 10	PHILIPPINE ISLANDS REGION
# 11	WESTERN TURKEY
# 12	SOUTHERN IDAHO
# 13	SAN FRANCISCO BAY AREA, CALIF.
# 14	PUERTO RICO REGION
# 15	COSTA RICA
# 16	CENTRAL ITALY
# 17	ISLAND OF HAWAII, HAWAII
# 18	TARAPACA, CHILE
# 19	VERACRUZ, MEXICO
# ```

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code

soup5 = make_soup('https://www.emsc-csem.org/Earthquake/')
info = soup5.find_all('td')

# [i.text for i in info]

# [i.text for i in info if i.text.startswith('earthquake')]

info = soup5.find_all('td', {'class': 'tb_region'})[0:20]
[i.text.replace('\xa0', '') for i in info]

# [i.text for i in info]
# Out:
# ['MINDANAO, PHILIPPINES',
#  'NORTHERN SUMATRA, INDONESIA',
#  'OFFSHORE CHIAPAS, MEXICO',
#  'OFFSHORE ATACAMA, CHILE',
#  'NEAR THE COAST OF WESTERN TURKEY',
#  'DOMINICAN REPUBLIC REGION',
#  'NORTHERN ITALY',
#  'TAIWAN',
#  'NORTHERN CALIFORNIA',
#  'OFFSHORE CHIAPAS, MEXICO',
#  'PUERTO RICO REGION',
#  'KEPULAUAN TALAUD, INDONESIA',
#  'NEAR N COAST OF PAPUA, INDONESIA',
#  'JUJUY, ARGENTINA',
#  'ANTOFAGASTA, CHILE',
#  'TENNESSEE',
#  'CENTRAL PERU',
#  'OFF COAST OF CHIAPAS, MEXICO',
#  'OFF COAST OF COQUIMBO, CHILE',
#  'FRANCE']

# %%
rows = soup5.find_all('tbody', 'id'=={'tbody'})
rows

[i.text.split() for i in rows if i.endswith('</td></tr>')] # try to extract the strings that end with format xxxx-xx-xx for the date. See credit card solution as example!!

# '<tr id="910689" class="ligne1 normal" onclick="go_details(event,910689);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=910689">2020-10-12&nbsp;&nbsp;&nbsp;17:00:54.0</a></b><i class="ago" id="ago0">18min ago</i></td><td class="tabev1">9.64&nbsp;</td><td class="tabev2">N&nbsp;&nbsp;</td><td class="tabev1">126.27&nbsp;</td><td class="tabev2">E&nbsp;&nbsp;</td><td class="tabev3">13</td><td class="tabev5" id="magtyp0"> M</td><td class="tabev2">3.4</td><td id="reg0" class="tb_region">&nbsp;MINDANAO, PHILIPPINES</td><td class="comment updatetimeno" id="upd0" style="text-align:right;">2020-10-12 17:10</td></tr>'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-dc100f45a5d6> in <module>
#       2 rows
#       3
# ----> 4 [i.text.split() for i in rows if i.endswith('</td></tr>')] # try to extract the strings that end with format xxxx-xx-xx for the date. See credit card solution as example!!
#       5
# ...

# %%
# '<td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=910689">2020-10-12&nbsp;&nbsp;&nbsp;17:00:54.0</a></b><i class="ago" id="ago0">21min ago</i></td>'

# %%
# pd.DataFrame(info)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-c73f0a2cfb4d> in <module>
# ----> 1 pd.DataFrame(info)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     486                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     487                 else:
# --> 488                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     489             else:
#     490                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     167     # by definition an array here
#     168     # the dtypes will be coerced to a single dtype
# --> 169     values = prep_ndarray(values, copy=copy)
#     170
# ...

# %% [markdown]
# ## Bonus Questions

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code
# URL didnt work for me

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code
response = make_soup(url)
response
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
# <link href="//abs.twimg.com" rel="preconnect"/>
# <link href="//api.twitter.com" rel="preconnect"/>
# <link href="//pbs.twimg.com" rel="preconnect"/>
# <link href="//t.co" rel="preconnect"/>
# <link href="//video.twimg.com" rel="preconnect"/>
# <link href="//abs.twimg.com" rel="dns-prefetch"/>
# <link href="//api.twitter.com" rel="dns-prefetch"/>
# <link href="//pbs.twimg.com" rel="dns-prefetch"/>
# <link href="//t.co" rel="dns-prefetch"/>
# <link href="//video.twimg.com" rel="dns-prefetch"/>
# <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/client-web-legacy/polyfills.a4038a25.js" nonce="MmM4ZTFlZDMtNGRiYi00Yjc1LTkxNzctNzA4ZDZmNzA0MzBj" rel="preload"/>
# ...

# %%
# Tried from solutions:

user = input("Enter your twitter handle: ")
temp = requests.get('https://twitter.com/' + user)
bs = BeautifulSoup(temp.text,'lxml')

try:
    tweet_box = bs.find('li', {'class': 'ProfileNav-item'})
# Out:
# Enter your twitter handle: kate_saslow

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
